# %% [markdown]
# # <p style="color:DarkGreen;">Pregunta 2</p>
#
# #  <p style="color:DarkBlue;">¿El **web scraping** es legal o no?, ¿y en Perú?</p>
# Hoy en día la información es el valor más importante para las empresas, por lo que es habitual que utilicen herramientas y métodos para automatizar y obtener datos. Una técnica muy utilizada por la mayoría de empresas para extraer información de páginas web de forma automatizada es el __*web scraping*__.
#
# A modo de introducción, veremos algunos conceptos como: que es el web scraping, para que sirven extraer los datos de una web, como hacer scraping de una página web,como evitar el scrapping de una página de datos y, finalmente, si este accionar es legal o no en el Perú.
#
# ![webscraping](https://www.grid.cl/blog/wp-content/uploads/2019/03/001-efficient-web-scraping.png)
#
# ## ¿Qué es web scraping?
#
# El web scraping o “escarbar en una página web” es una técnica que se utiliza para obtener información de forma automática de páginas web. El scraping es la extracción de información web con el objetivo de conseguir un gran volumen de datos (Big Data) sin necesidad de que intervenga una persona en el proceso. Es decir, consiste en copiar información de otra pagina web para el uso propio.
# ## ¿Para que sirve extraer los datos de una web?
#
# Sus funciones principales son:
#
# - <span style="color:red;">Scraping de precios:</span>
# El estudio de los precios de la competencia es una técnica que utilizan las empresas para conocer mejor el mercado en busca de una ventaja competitiva.
#
# - <span style="color:red;">Gestión de contenido:</span>
# Uno de los primeros usos de esta técnica era reunir en un único sitio web noticias y ofertas sobre una determinada temática (ofertas inmobiliarias o venta de coches, por ejemplo).
#
# - <span style="color:red;">Medir opiniones:</span>
# Con el scraping se buscan las opiniones sobre productos, marcas, personas, etc. Esto permitirá conocer la reputación y prestigio, asi como ver las tendencias del mercado.
#
# - <span style="color:red;">Monitorizar a la competencia:</span>
# El web scraping puede realizar funciones para tener controlada a la competencia y poder detectar sus movimientos a través de la información que añaden y modifican de sus sitios web. Es muy útil para detectar modificaciones en catálogos, actualizaciones de páginas web, descubrir si mencionan productos o utilizan contenido que no son suyos y muchas otras utilidades.
#
#
# ## ¿Cómo hacer un scraping de una página web?
#
# Hay diferentes métodos para realizar web scraping y obtener datos de una página web. El método más habitual es el uso de *programas informáticos* o extensiones para los navegadores web, que automatizan todo el proceso.
#
# ## ¿Cómo evitar el scrapping de una página de datos?
#
# Para evitar que scrapeen tu página se recomienda lo siguiente:
# - Bloquear los bots en el archivo robots.txt. Se puede hacer a través de Google Search Console o desde el propio panel de control de la web.
# - Insertar captchas contra los bots(aunque hay algunos que ya son capaces de evitarlos)
# - Implementar un sistema de cookies para verificar que el visitante es un navegador. Utiliza un código Javascript ya que la mayora de bots y arañas no pueden leerlos.
#
# ## ¿El **web scraping** es legal o no?
#
# En relación a la legislación, en la mayoría de países no existe una legislación clara y precisa respecto el webcraping en sí, y los tribunales aún no mantienen una postura uniforme. Se puede decir que esta <span style="color:brown;">**PRACTICA EN SÍ NO ES ILEGAL**</span>, pero que <span style="color:brown;">**ES ILEGAL A TRAVÉS DE ESTA PRACTICA VIOLAR LOS DERECHOS DE AUTOR, PROPIEDAD INTELECTUAL O USO DE MARCA REGISTRADAS O ESTAR REALIZANDO COMPETENCIA DESLEAL**</span>
#
# A modo de ejemplo, en el año 2012, en España la empresa Ryanair (compañía aérea) demandó a la empresa Atrapalo (agencia de viajes). Ryanair los acusó de scrapear su página web para obtener obtener información y competir de una manera desleal. Los juzgados españoles determinaron que ese tipo de webscrapping era *legal*, pero debemos aclarar que no todo webscrappig es legal. Para ello, más que el comportamiento debemos analizar cuales son las consecuencias de su uso.
#
# Sin entrar en los pormenores de la Sentencia, y de forma sucinta, pasaremos a señalar los diferentes puntos que entran en juego a la hora de determinar la legalidad del web scraping:
#
# - El riesgo de incurrir en una vulneración de los derechos de propiedad intelectual de los titulares de la página web, en aquellos casos en los que se demuestre la estructura original de la base de datos objeto del web scraping convirtiéndola en obra intelectualmente protegida. O, a pesar de que la base de datos no esté dotada de dicha originalidad, siempre que la creación de la misma haya supuesto una inversión sustancial por parte de su fabricante, ya que podría ser susceptible de ser protegida a través del derecho sui generis (Título VIII de la LPI).
#
# - La posible consideración de una conducta de competencia desleal cuando la finalidad llevada a cabo por aquellos terceros que aplican las técnicas de web scraping sea susceptible de ser considerada una imitación, al ofrecer servicios similares a los prestados por el website objeto de scraping, suponiendo un riesgo de confusión por parte de los usuarios o el aprovechamiento indebido de la reputación o esfuerzo ajeno.
#
# - Una eventual violación de los términos legales y condiciones de uso establecidos por los titulares del website objeto de scraping, desde el momento en el que los mismos sean aceptados por los usuarios que naveguen por la página web y tengan acceso a la información contenida en la misma.
#
# - El potencial incumplimiento de la normativa en protección de datos y la vulneración de los derechos de los titulares de los datos personales objeto de scraping,ya que se exige que se cuente con el consentimiento del titular de los datos a la hora de proceder al almacenamiento y tratamiento de los mismos, debiendo, por otra parte, estar este informado de las finalidades del mencionado tratamiento.
#
# En la **_legislación peruana_**, el escrapeo de páginas web no esta tipificado como algo ilegal. Lo que si son delitos es el mal manejo de estos datos o información que se reune. Como por ejemplo, La ley N°29733 (la ley de protección de datos personales) como se mencionó en el punto anterior, no pueden manejar o tratar información de otra persona si es que esta no hay dado la autorización. Asimismo, en el Decreto Legislativo N°822 (Ley sobre el derecho de autor) se afirman los derechos y patrimonios que la ley concede a los autores bajo un conjunto de normas jurídicas. Y asi no vulnerar los derechos de propiedad intelectual de los titulares.
#
# ## Conclusiones
#
# Aunque los datos se encuentren publicados en websites de tal forma que cualquiera pueda acceder a los mismos, esto no significa que puedan ser utilizados de forma indiscriminada para cualquier finalidad, yendo contra los intereses del propietario original y sin contar con el consentimiento previo de los titulares de los datos. Por tanto, debemos actuar con cautela, plantearnos una posible confrontación entre nuestra finalidad y la del propio website y realizar un análisis previo de las páginas objeto de scraping así como de sus términos y condiciones de uso, garantizando, en todo caso, que no se está incurriendo en una actividad ilegal en base a todos los puntos anteriormente expuestos.
#
# ## Bibliografía
# 1. [Qué es y cómo hacer web scraping](https://www.hostingplus.pe/blog/que-es-y-como-hacer-web-scraping/)
# 2. [¿Es legal el web scraping? : De webscraping y legalidad](https://diariodeuneletrado.wordpress.com/2017/03/22/es-legal-el-web-scrapping-de-webscrapping-y-legalidad/)
# 3. [¿El web scraping es legal?](http://www.blogdederecho.es/2017/06/el-web-scraping-es-legal/)
# 4. [Web Scraping: ¿legal o ilegal?](https://ecija.com/web-scraping-legal-ilegal/)
# 5. [Normas legales](https://diariooficial.elperuano.pe/pdf/0036/ley-proteccion-datos-personales.pdf)
